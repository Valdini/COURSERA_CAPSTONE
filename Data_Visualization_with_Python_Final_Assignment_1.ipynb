# %% [markdown]
# <a href="https://colab.research.google.com/github/Valdini/COURSERA_CAPSTONE/blob/main/Data_Visualization_with_Python_Final_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #importing pandas
df_data = pd.read_csv('https://cocl.us/datascience_survey_data',index_col=False) #reading data
df_data.columns = ['','Very interested','Somewhat interested','Not interested'] #setting/renaming table columns
df_data
# Out:
#                                ...  Not interested
# 0   Big Data (Spark / Hadoop)  ...             127
# 1  Data Analysis / Statistics  ...              60
# 2             Data Journalism  ...             610
# 3          Data Visualization  ...             102
# 4               Deep Learning  ...             136
# 5            Machine Learning  ...              74
#
# [6 rows x 4 columns]

# %%
df_data.sort_values(by='Very interested',ascending='False')
for col in df_data.columns[1:]:
  df_data[col] = (100. * df_data[col] / 2233).round(2)
df_data
# Out:
#                                ...  Not interested
# 0   Big Data (Spark / Hadoop)  ...            5.69
# 1  Data Analysis / Statistics  ...            2.69
# 2             Data Journalism  ...           27.32
# 3          Data Visualization  ...            4.57
# 4               Deep Learning  ...            6.09
# 5            Machine Learning  ...            3.31
#
# [6 rows x 4 columns]

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
labels = df_data['']
very_int = df_data['Very interested']
some_int = df_data['Somewhat interested']
not_int = df_data['Not interested']
ind = np.arange(len(very_int))
width = 0.3
fig, ax = plt.subplots(figsize=(23,8))
rects1 = ax.bar(ind - width, very_int, width, label='Very interested', color='#5cb85c')
rects2 = ax.bar(ind, some_int, width, label='Somewhat interested', color='#5bc0de')
rects3 = ax.bar(ind + width, not_int, width, label='Not interested', color='#d9534f')
ax.set_title("Percentage of Respondents' Interest In Data Science Areas", fontsize=16)
ax.set_xticks(ind)
ax.set_xticklabels((labels),rotation='vertical',fontsize=14)
ax.get_yaxis().set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.legend(fontsize=14,loc="upper right")
def autolabel(rects, xpos='center'):
    ha = {'center': 'center', 'right': 'left', 'left': 'right'}
    offset = {'center': 0, 'right': 1, 'left': -1}
    for rect in rects:
        height = rect.get_height().round(2)
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(offset[xpos]*3, 3),  
                    textcoords="offset points", 
                    ha=ha[xpos], va='bottom', fontsize=14)
autolabel(rects1, "center")
autolabel(rects2, "center")
autolabel(rects3, "center")
fig.tight_layout()
plt.show()
